# %% [markdown]
# # 31_july_ClassAssignment_Task2

# %% [raw]
# #super store usa data
# 1. load this data in pandas , sql with a relation in sql
# 2. while loading this data you dont have to create table manually you can use any automated approach to create a table and load the data in bulk in table
# 3. find out how many return that we have recieved and wiht a product id
# 4. try to join order and return data sql and pandas
# 5. try to find out how many unique consumers we have
# 6. try to find out how many regions we are selling a product and who is manager for respective region
# 7. find out how many different shipment mode we have and what uis a percentage usability of all the shipment mode respect to dataset
# 8. create a new column and try to find out a difference between order date and shipment date
# 9. based on q8 find out which order id we have shipment duration more than 10 days
# 10. try to find out a list of returned order which shipment was more than 15 days and fid out that region manager
# 11. group by region and find out which region is more profitable
# 12. try to find out overall in which country we are giving more discount
# 13. give me a list of unique postal code
# 14. which consumer segment is more profitable find it out
# 15. try to find out the 10th most loss making product category
# 16. try tto find out 10 top the product with most margins

# %%
import pandas as pd

# %%
import mysql.connector

# %%
mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  password="indore11"
)

# %%
print(mydb)

# %%
cursor = mydb.cursor()

# %%
cursor.execute('USE assignment')

# %%
cursor.execute("SHOW DATABASES")

# %%
for i in cursor.fetchall():
    print(i)
# Out:
# ('assignment',)
# ('hitesh',)
# ('information_schema',)
# ('invoicing',)
# ('learnsql',)
# ('mysql',)
# ('performance_schema',)
# ('sakila',)
# ('sql_hr',)
# ('sql_inventory',)
# ('sql_invoicing',)
# ('sql_store',)
# ('store',)
# ('sys',)
# ('testdatabase',)
# ('world',)

# %% [markdown]
# ### 1. load this data in pandas , sql with a relation in sql

# %%
orders =  pd.read_excel('31_july_dataset/Superstore_USA.xlsx')

# %%
orders.head()
# Out:
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0   18606  Not Specified      0.01        2.88           0.50            2
# 1   20847           High      0.01        2.84           0.93            3
# 2   23086  Not Specified      0.03        6.68           6.15            3
# 3   23087  Not Specified      0.01        5.68           3.60            3
# 4   23088  Not Specified      0.00      205.99           2.50            3
#
#      Customer Name    Ship Mode Customer Segment Product Category  ...  \
# 0  Janice Fletcher  Regular Air        Corporate  Office Supplies  ...
# 1    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
# 2    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
# 3    Bonnie Potter  Regular Air        Corporate  Office Supplies  ...
# 4    Bonnie Potter  Express Air        Corporate       Technology  ...
#
#     Region State or Province       City  Postal Code Order Date  Ship Date  \
# ...

# %%
returns = pd.read_excel('31_july_dataset/Superstore_USA.xlsx',sheet_name='Returns')

# %%
returns.head()
# Out:
#    Order ID    Status
# 0        65  Returned
# 1       612  Returned
# 2       614  Returned
# 3       678  Returned
# 4       710  Returned

# %%
users = pd.read_excel('31_july_dataset/Superstore_USA.xlsx',sheet_name='Users')

# %%
users.head()
# Out:
#     Region  Manager
# 0  Central    Chris
# 1     East     Erin
# 2    South      Sam
# 3     West  William

# %%
from sqlalchemy import create_engine

# %%
conn_str = 'mysql+pymysql://root:indore11@localhost:3306/assignment'

# %%
db_connection = create_engine(conn_str)

# %%
print(db_connection)
# Out:
# Engine(mysql+pymysql://root:***@localhost:3306/assignment)

# %%
try:
    orders.to_sql(name='orders',con=db_connection,index=False)
except Exception as e:
    print(e)

# %%
try:
    returns.to_sql(name='returns',con=db_connection,index=False)
except Exception as e:
    print(e)

# %%
try:
    users.to_sql(name='users',con=db_connection,index=False)
except Exception as e:
    print(e)

# %%
#in sql i run the commands to make relation between tables (add primary and foreign keys)
ALTER TABLE users 
MODIFY `Region` VARCHAR(7) NOT NULL;

ALTER TABLE orders 
MODIFY `Region` VARCHAR(7) NOT NULL;

ALTER TABLE users
ADD PRIMARY KEY (`Region`);

ALTER TABLE orders
MODIFY `Order ID` bigint unique;

ALTER TABLE orders
ADD FOREIGN KEY(`Region`) REFERENCES users(`Region`);

ALTER TABLE `returns`
ADD PRIMARY KEY (`Order ID`);

SET FOREIGN_KEY_CHECKS=0;

ALTER TABLE orders
ADD FOREIGN KEY(`Order ID`) REFERENCES `returns`(`Order ID`);

# %% [markdown]
# ### 2. while loading this data you dont have to create table manually you can use any automated approach to create a table and load the data in bulk in table

# %%
# i use csv kit to make table automaticaly
#csvsql --dialect mysql --snifflimit 10000 test.csv > test.sql

# %%
#tables generated by csvkit

# %% [markdown]
# CREATE TABLE orders (
# 	`Row ID` DECIMAL(38, 0) NOT NULL,
# 	`Order Priority` VARCHAR(13) NOT NULL,
# 	`Discount` DECIMAL(38, 2) NOT NULL,
# 	`Unit Price` DECIMAL(38, 2) NOT NULL,
# 	`Shipping Cost` DECIMAL(38, 2) NOT NULL,
# 	`Customer ID` DECIMAL(38, 0) NOT NULL,
# 	`Customer Name` VARCHAR(28) NOT NULL,
# 	`Ship Mode` VARCHAR(14) NOT NULL,
# 	`Customer Segment` VARCHAR(14) NOT NULL,
# 	`Product Category` VARCHAR(15) NOT NULL,
# 	`Product Sub-Category` VARCHAR(30) NOT NULL,
# 	`Product Container` VARCHAR(30) NOT NULL,
# 	`Product Name` VARCHAR(98) NOT NULL,
# 	`Product Base Margin` DECIMAL(38, 2),
# 	`Region` VARCHAR(7) NOT NULL,
# 	`State or Province` VARCHAR(20) NOT NULL,
# 	`City` VARCHAR(19) NOT NULL,
# 	`Postal Code` DECIMAL(38, 0) NOT NULL,
# 	`Order Date` DATE NOT NULL,
# 	`Ship Date` DATE NOT NULL,
# 	`Profit` DECIMAL(38, 18) NOT NULL,
# 	`Quantity ordered new` DECIMAL(38, 0) NOT NULL,
# 	`Sales` DECIMAL(38, 2) NOT NULL,
# 	`Order ID` DECIMAL(38, 0) NOT NULL,
#     PRIMARY KEY (`Order ID`),
#     FOREIGN KEY(`Region`) REFERENCES users(`Region`)
# );

# %% [markdown]
# CREATE TABLE `returns` (
# 	`Order ID` DECIMAL(38, 0) NOT NULL,
# 	`Status` VARCHAR(8) NOT NULL,
#     PRIMARY KEY (`Order ID`),
#     FOREIGN KEY(`Order ID`) REFERENCES orders(`Order ID`)
# );

# %% [markdown]
# CREATE TABLE users (
# 	`Region` VARCHAR(7) NOT NULL,
# 	`Manager` VARCHAR(7) NOT NULL,
#     PRIMARY KEY (`Region`)
# );

# %% [markdown]
# ### 3. find out how many return that we have recieved and wiht a product id

# %%
returns.shape
# Out:
# (1634, 2)

# %%
returns.head()
# Out:
#    Order ID    Status
# 0        65  Returned
# 1       612  Returned
# 2       614  Returned
# 3       678  Returned
# 4       710  Returned

# %% [markdown]
# ### 4. try to join order and return data sql and pandas

# %%
#in sql orders and returns are joined in 1st question

# %%
pd.merge(orders,returns)
# Out:
#     Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0     1359            Low      0.05        5.85           2.27           21
# 1     1950         Medium      0.01        4.91           0.50          117
# 2     1951         Medium      0.09        4.00           1.30          117
# 3     5055           High      0.02        3.28           5.00          117
# 4     5573            Low      0.02       11.97           5.81          272
# ..     ...            ...       ...         ...            ...          ...
# 93     986  Not Specified      0.06       37.94           5.08         3075
# 94     987  Not Specified      0.10       55.29           5.08         3075
# 95    6041         Medium      0.05        4.28           6.18         3075
# 96    1910           High      0.05       14.48           1.99         3079
# 97    6625           High      0.06      128.24          12.65         3251
#
# ...

# %% [markdown]
# ### 5. try to find out how many unique consumers we have

# %%
len(orders['Customer ID'].unique())
# Out:
# 2703

# %% [markdown]
# ### 6. try to find out how many regions we are selling a product and who is manager for respective region

# %%
orders.head()
# Out:
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0   18606  Not Specified      0.01        2.88           0.50            2
# 1   20847           High      0.01        2.84           0.93            3
# 2   23086  Not Specified      0.03        6.68           6.15            3
# 3   23087  Not Specified      0.01        5.68           3.60            3
# 4   23088  Not Specified      0.00      205.99           2.50            3
#
#      Customer Name    Ship Mode Customer Segment Product Category  ...  \
# 0  Janice Fletcher  Regular Air        Corporate  Office Supplies  ...
# 1    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
# 2    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
# 3    Bonnie Potter  Regular Air        Corporate  Office Supplies  ...
# 4    Bonnie Potter  Express Air        Corporate       Technology  ...
#
#     Region State or Province       City  Postal Code Order Date  Ship Date  \
# ...

# %%
orders.Region.unique()
# Out:
# array(['Central', 'West', 'East', 'South'], dtype=object)

# %%
users.head()
# Out:
#     Region  Manager
# 0  Central    Chris
# 1     East     Erin
# 2    South      Sam
# 3     West  William

# %% [markdown]
# ### 7. find out how many different shipment mode we have and what uis a percentage usability of all the shipment mode respect to dataset

# %%
orders['Ship Mode'].value_counts() / len(orders) * 100
# Out:
# Regular Air       74.644600
# Delivery Truck    13.611288
# Express Air       11.744112
# Name: Ship Mode, dtype: float64

# %% [markdown]
# ### 8. create a new column and try to find out a difference between order date and shipment date

# %%
orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9426 entries, 0 to 9425
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Row ID                9426 non-null   int64
#  1   Order Priority        9426 non-null   object
#  2   Discount              9426 non-null   float64
#  3   Unit Price            9426 non-null   float64
#  4   Shipping Cost         9426 non-null   float64
#  5   Customer ID           9426 non-null   int64
#  6   Customer Name         9426 non-null   object
#  7   Ship Mode             9426 non-null   object
#  8   Customer Segment      9426 non-null   object
#  9   Product Category      9426 non-null   object
#  10  Product Sub-Category  9426 non-null   object
#  11  Product Container     9426 non-null   object
#  12  Product Name          9426 non-null   object
#  13  Product Base Margin   9354 non-null   float64
#  14  Region                9426 non-null   object
# ...

# %%
orders['time_to_reach'] = orders['Ship Date'] - orders['Order Date']

# %%
orders.head()
# Out:
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0   18606  Not Specified      0.01        2.88           0.50            2
# 1   20847           High      0.01        2.84           0.93            3
# 2   23086  Not Specified      0.03        6.68           6.15            3
# 3   23087  Not Specified      0.01        5.68           3.60            3
# 4   23088  Not Specified      0.00      205.99           2.50            3
#
#      Customer Name    Ship Mode Customer Segment Product Category  ...  \
# 0  Janice Fletcher  Regular Air        Corporate  Office Supplies  ...
# 1    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
# 2    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
# 3    Bonnie Potter  Regular Air        Corporate  Office Supplies  ...
# 4    Bonnie Potter  Express Air        Corporate       Technology  ...
#
#   State or Province       City Postal Code  Order Date  Ship Date    Profit  \
# ...

# %% [markdown]
# ### 9. based on q8 find out which order id we have shipment duration more than 10 days

# %%
orders[orders.time_to_reach.dt.days > 10]
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 643    18246       Critical      0.05       11.09           5.25          250
# 1548   23091         Medium      0.04      100.98           7.18          595
# 1549   23092         Medium      0.09        6.48           7.49          595
# 1678   20703  Not Specified      0.07      130.98          30.00          637
# 1679   20704  Not Specified      0.09       55.98           4.86          637
# 1680   20705  Not Specified      0.08      115.99           4.23          637
# 1697    2703  Not Specified      0.07      130.98          30.00          640
# 1698    2704  Not Specified      0.09       55.98           4.86          640
# 1699    2705  Not Specified      0.08      115.99           4.23          640
# 2515   18060            Low      0.02        2.21           1.00          964
# 5548   21603  Not Specified      0.02        5.58           1.99         2048
# ...

# %% [markdown]
# ### 10. try to find out a list of returned order which shipment was more than 15 days and fid out that region manager

# %%
df1 = pd.merge(orders,returns)

# %%
df2 = pd.merge(df1,users)

# %%
df2[df2.time_to_reach.dt.days > 15]
# Out:
# Empty DataFrame
# Columns: [Row ID, Order Priority, Discount, Unit Price, Shipping Cost, Customer ID, Customer Name, Ship Mode, Customer Segment, Product Category, Product Sub-Category, Product Container, Product Name, Product Base Margin, Region, State or Province, City, Postal Code, Order Date, Ship Date, Profit, Quantity ordered new, Sales, Order ID, time_to_reach, Status, Manager]
# Index: []
#
# [0 rows x 27 columns]

# %% [markdown]
# ### 11. group by region and find out which region is more profitable

# %%
orders.groupby('Region')['Profit'].sum().idxmax()
# Out:
# 'Central'

# %% [markdown]
# ### 12. try to find out overall in which country we are giving more discount

# %%
orders.head()
# Out:
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0   18606  Not Specified      0.01        2.88           0.50            2
# 1   20847           High      0.01        2.84           0.93            3
# 2   23086  Not Specified      0.03        6.68           6.15            3
# 3   23087  Not Specified      0.01        5.68           3.60            3
# 4   23088  Not Specified      0.00      205.99           2.50            3
#
#      Customer Name    Ship Mode Customer Segment Product Category  ...  \
# 0  Janice Fletcher  Regular Air        Corporate  Office Supplies  ...
# 1    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
# 2    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
# 3    Bonnie Potter  Regular Air        Corporate  Office Supplies  ...
# 4    Bonnie Potter  Express Air        Corporate       Technology  ...
#
#   State or Province       City Postal Code  Order Date  Ship Date    Profit  \
# ...

# %%
orders.groupby('State or Province')['Discount'].sum().sort_values(ascending=False).head(10) #top 10 states
# Out:
# State or Province
# California      52.28
# Texas           31.36
# Illinois        29.71
# New York        28.86
# Florida         26.38
# Ohio            19.71
# Washington      15.48
# Michigan        15.29
# Pennsylvania    13.32
# Minnesota       12.52
# Name: Discount, dtype: float64

# %% [markdown]
# ### 13. give me a list of unique postal code

# %%
len(orders['Postal Code'].unique())
# Out:
# 1697

# %%
orders['Postal Code'].unique()
# Out:
# array([60101, 98221, 91776, ..., 61832, 62521, 26554], dtype=int64)

# %% [markdown]
# ### 14. which consumer segment is more profitable find it out

# %%
orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9426 entries, 0 to 9425
# Data columns (total 25 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Row ID                9426 non-null   int64
#  1   Order Priority        9426 non-null   object
#  2   Discount              9426 non-null   float64
#  3   Unit Price            9426 non-null   float64
#  4   Shipping Cost         9426 non-null   float64
#  5   Customer ID           9426 non-null   int64
#  6   Customer Name         9426 non-null   object
#  7   Ship Mode             9426 non-null   object
#  8   Customer Segment      9426 non-null   object
#  9   Product Category      9426 non-null   object
#  10  Product Sub-Category  9426 non-null   object
#  11  Product Container     9426 non-null   object
#  12  Product Name          9426 non-null   object
#  13  Product Base Margin   9354 non-null   float64
#  14  Region                9426 non-null   object
# ...

# %%
orders.groupby('Customer Segment')['Profit'].sum().idxmax()
# Out:
# 'Corporate'

# %% [markdown]
# ### 15. try to find out the 10th most loss making product category

# %%
orders.head()
# Out:
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0   18606  Not Specified      0.01        2.88           0.50            2
# 1   20847           High      0.01        2.84           0.93            3
# 2   23086  Not Specified      0.03        6.68           6.15            3
# 3   23087  Not Specified      0.01        5.68           3.60            3
# 4   23088  Not Specified      0.00      205.99           2.50            3
#
#      Customer Name    Ship Mode Customer Segment Product Category  ...  \
# 0  Janice Fletcher  Regular Air        Corporate  Office Supplies  ...
# 1    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
# 2    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
# 3    Bonnie Potter  Regular Air        Corporate  Office Supplies  ...
# 4    Bonnie Potter  Express Air        Corporate       Technology  ...
#
#   State or Province       City Postal Code  Order Date  Ship Date    Profit  \
# ...

# %%
orders[orders.Profit < 0].sort_values('Profit',ascending=True).iloc[10,9]
# Out:
# 'Technology'

# %% [markdown]
# ### 16. try to find out 10 top products with most margins

# %%
orders.sort_values('Profit',ascending=False).iloc[:10,12].tolist()
# Out:
# ['Sanyo 2.5 Cubic Foot Mid-Size Office Refrigerators',
#  'Fellowes PB500 Electric Punch Plastic Comb Binding Machine with Manual Bind',
#  'Fellowes PB300 Plastic Comb Binding Machine',
#  'Fellowes PB500 Electric Punch Plastic Comb Binding Machine with Manual Bind',
#  'Okidata ML184 Turbo Dot Matrix Printers',
#  'Hewlett-Packard cp1700 [D, PS] Series Color Inkjet Printers',
#  'Hewlett Packard LaserJet 3310 Copier',
#  "Honeywell Enviracaire Portable HEPA Air Cleaner for 17' x 22' Room",
#  'Epson LQ-870 Dot Matrix Printer',
#  'Polycom ViaVideo™ Desktop Video Communications Unit']
